# %%
import selenium
from bs4 import BeautifulSoup
import urllib2
import json

import re
from selenium import webdriver
from selenium.webdriver.support.ui import Select
import time

import pandas as pd
import numpy as np

# %% [markdown]
# ## Define values for combinations

# %%
CAR_MODEL = ['TOYOTA COROLLA ALTIS','HONDA CIVIC']
CAR_ENGINE = ['1600','1700']
CAR_REGIS = ['2016','2017']
OFF_PEAK = ['YES','NO'] 
GENDER = ['MALE','FEMALE']
MARITAL = ['SINGLE','MARRIED']
BIRTHDATE = ['01/01/1993','01/01/1983']
DRI_EXP = ['LESS_TWO','MORE_TWO']
CLM_PST = ['YES','NO']
#NCD = [0,20]

# %% [markdown]
# ## Create combination dataframe

# %%
df_model = pd.DataFrame(data = ['TOYOTA COROLLA ALTIS','HONDA CIVIC'], columns=['CAR_MODEL'])
df_model['tmp_key'] = 1

df_engine = pd.DataFrame(data = ['1600','1700'], columns=['CAR_ENGINE'])
df_engine['tmp_key'] = 1

df_regis = pd.DataFrame(data = ['2016','2017'], columns=['CAR_REGIS'])
df_regis['tmp_key'] = 1

df_offpeak = pd.DataFrame(data = ['YES','NO'], columns=['OFF_PEAK'])
df_offpeak['tmp_key'] = 1

df_gender = pd.DataFrame(data = ['MALE','FEMALE'], columns=['GENDER'])
df_gender['tmp_key'] = 1

df_marital = pd.DataFrame(data = ['SINGLE','MARRIED'], columns=['MARITAL'])
df_marital['tmp_key'] = 1

df_birthdate = pd.DataFrame(data = ['01/01/1993','01/01/1983'], columns=['BIRTHDATE'])
df_birthdate['tmp_key'] = 1

df_driexp = pd.DataFrame(data = ['LESS_TWO','MORE_TWO'], columns=['DRI_EXP'])
df_driexp['tmp_key'] = 1

df_clmpst = pd.DataFrame(data = ['NO'], columns=['CLM_PST'])
df_clmpst['tmp_key'] = 1

# %%
df = df_model.merge(df_engine,how='outer')

# %%
for tmp_df in [df_regis, df_offpeak, df_gender, df_marital, df_birthdate, df_driexp, df_clmpst]:
    df = df.merge(tmp_df, how='outer')

# %%
df['plan_name'] = 'Drivo Classic Plan'
df['plan_quotes'] = 0.0

# %% [markdown]
# ## Scrap for 10 combinations for test

# %%
df_test = df.sample(10).reset_index(drop=True)

# %%
#initialize selenium chrom driver
path_to_chromedriver = 'C:\Users\liuleo\Documents\Python\chromedriver_win32\chromedriver.exe' 
browser = webdriver.Chrome(executable_path = path_to_chromedriver)

# navigate to the webpage containing information to be crawled
url = 'https://insurance.income.com.sg/quote/car/index/'
browser.get(url)

# %%
for i in range(len(df_test)):
    print df_test.loc[i, 'CAR_MODEL'], df.loc[i, 'CAR_ENGINE'], df.loc[i, 'DRI_EXP'], df.loc[i, 'CLM_PST']
    # select car model 
    select_car_model = Select(browser.find_element_by_id('carMakeModel'))
    select_car_model.select_by_visible_text(df_test.loc[i, 'CAR_MODEL'])
    
    # select car engine
    select_car_eng = Select(browser.find_element_by_id('engineCapacities_car'))
    select_car_eng.select_by_visible_text(df_test.loc[i, 'CAR_ENGINE'])
    
    # sleep before input text 
    time.sleep(1)
    #input car registered year
    browser.find_element_by_xpath('//*[@id="input-moto-year"]').send_keys(df_test.loc[i, 'CAR_REGIS'])
    
    # select Off-Peak Car Scheme (default value is no)
    if df_test.loc[i, 'OFF_PEAK'] == 'YES':
        browser.find_element_by_xpath('//*[@id="tab1"]/div/div[4]/div/div/label[1]').click()
    #else:
    #    browser.find_element_by_xpath('//*[@id="tab1"]/div/div[4]/div/div/label[2]').click()
    
    #click next
    browser.find_element_by_xpath('//*[@id="tab1"]/div/ul/li/a').click()
    # sleep when goes to a new page
    time.sleep(1)
    
    #select gender (default is male)
    if df_test.loc[i, 'GENDER'] == 'FEMALE':
        browser.find_element_by_xpath('//*[@id="tab2"]/div/div[1]/div/div[1]/label[2]').click()        
    #else:
    #    browser.find_element_by_xpath('//*[@id="tab2"]/div/div[1]/div/div[1]/label[1]').click()
    
    #select marital status (default single)
    if df_test.loc[i, 'MARITAL'] == 'MARRIED':
        browser.find_element_by_xpath('//*[@id="tab2"]/div/div[2]/div/div[1]/label[2]').click()
    #else:
    #    browser.find_element_by_xpath('//*[@id="tab2"]/div/div[2]/div/div[1]/label[1]').click()
    
    time.sleep(2)
    
    #input date of birth
    browser.find_element_by_xpath('//*[@id="date"]').send_keys(df_test.loc[i, 'BIRTHDATE'])
    
    #click next
    browser.find_element_by_xpath('//*[@id="tab2"]/div/ul/li[2]/a').click()
    # sleep when goes to a new page
    time.sleep(1)
    
    #choose driver years exp (no default value)
    if df_test.loc[i, 'DRI_EXP'] == 'LESS_TWO':
        browser.find_element_by_xpath('//*[@id="tab3"]/div/div[1]/div/div[1]/label[1]').click()
    else:
        browser.find_element_by_xpath('//*[@id="tab3"]/div/div[1]/div/div[1]/label[2]').click()
    
    #choos flag for claim for last 3 years (if yes, then provide name and phone, qutoes will be given after call)
    #if df_test.loc[i, 'CLM_PST'] == 'YES':
    #    browser.find_element_by_xpath('//*[@id="tab3"]/div/div[2]/div/div/label[2]').click()
        
    #click next
    time.sleep(1)
    browser.find_element_by_xpath('//*[@id="tab3"]/div/ul/li[2]/a').click()
    time.sleep(1)
    
    #click confirm and get the quote
    browser.find_element_by_xpath('//*[@id="tab4"]/div[1]/button').click()
    
    time.sleep(4)
    html = browser.page_source
    # pass to BeautifulSoup parser
    soup = BeautifulSoup(html, "lxml")
    
    # Get basic plan
    name_box = soup.find_all('span', attrs={'class': 'plan-title'})

    basic_plan_name = name_box[0].text.strip()
    print basic_plan_name
    
    df_test.loc[i,'plan_name'] = basic_plan_name
    
    # Get price
    price_box = soup.find_all('p',attrs={'id':'plan_price_before_GST_1'})
    price = price_box[0].text.strip()
    
    df_test.loc[i,'plan_quotes'] = price
    
    time.sleep(1)
    # start a new quote
    url = 'https://insurance.income.com.sg/quote/car/index/'
    browser.get(url)
    # accept the alert 
    #browser.switch_to_alert().accept()
    time.sleep(1)
# Out:
# HONDA CIVIC 1600 LESS_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1600 MORE_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1600 LESS_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1600 MORE_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1600 LESS_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1600 MORE_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1600 LESS_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1600 MORE_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1600 LESS_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1600 MORE_TWO NO
# Drivo Classic Plan

# %% [markdown]
# ## Scrap all combinations (2^8 ~ 256)

# %%
#initialize selenium chrom driver
path_to_chromedriver = 'C:\Users\liuleo\Documents\Python\chromedriver_win32\chromedriver.exe' 
browser = webdriver.Chrome(executable_path = path_to_chromedriver)

# navigate to the webpage containing information to be crawled
url = 'https://insurance.income.com.sg/quote/car/index/'
browser.get(url)

# %%
for i in range(len(df)):
    print df.loc[i, 'CAR_MODEL'], df.loc[i, 'CAR_ENGINE'], df.loc[i, 'DRI_EXP'], df.loc[i, 'CLM_PST']
    # select car model 
    select_car_model = Select(browser.find_element_by_id('carMakeModel'))
    select_car_model.select_by_visible_text(df.loc[i, 'CAR_MODEL'])
    
    # select car engine
    select_car_eng = Select(browser.find_element_by_id('engineCapacities_car'))
    select_car_eng.select_by_visible_text(df.loc[i, 'CAR_ENGINE'])
    
    # sleep before input text 
    time.sleep(1)
    #input car registered year
    browser.find_element_by_xpath('//*[@id="input-moto-year"]').send_keys(df.loc[i, 'CAR_REGIS'])
    
    # select Off-Peak Car Scheme (default value is no)
    if df.loc[i, 'OFF_PEAK'] == 'YES':
        browser.find_element_by_xpath('//*[@id="tab1"]/div/div[4]/div/div/label[1]').click()
    #else:
    #    browser.find_element_by_xpath('//*[@id="tab1"]/div/div[4]/div/div/label[2]').click()
    
    #click next
    browser.find_element_by_xpath('//*[@id="tab1"]/div/ul/li/a').click()
    # sleep when goes to a new page
    time.sleep(1)
    
    #select gender (default is male)
    if df.loc[i, 'GENDER'] == 'FEMALE':
        browser.find_element_by_xpath('//*[@id="tab2"]/div/div[1]/div/div[1]/label[2]').click()        
    #else:
    #    browser.find_element_by_xpath('//*[@id="tab2"]/div/div[1]/div/div[1]/label[1]').click()
    
    #select marital status (default single)
    if df.loc[i, 'MARITAL'] == 'MARRIED':
        browser.find_element_by_xpath('//*[@id="tab2"]/div/div[2]/div/div[1]/label[2]').click()
    #else:
    #    browser.find_element_by_xpath('//*[@id="tab2"]/div/div[2]/div/div[1]/label[1]').click()
    
    time.sleep(2)
    
    #input date of birth
    browser.find_element_by_xpath('//*[@id="date"]').send_keys(df.loc[i, 'BIRTHDATE'])
    
    #click next
    browser.find_element_by_xpath('//*[@id="tab2"]/div/ul/li[2]/a').click()
    # sleep when goes to a new page
    time.sleep(1)
    
    #choose driver years exp (no default value)
    if df.loc[i, 'DRI_EXP'] == 'LESS_TWO':
        browser.find_element_by_xpath('//*[@id="tab3"]/div/div[1]/div/div[1]/label[1]').click()
    else:
        browser.find_element_by_xpath('//*[@id="tab3"]/div/div[1]/div/div[1]/label[2]').click()
    
    #choos flag for claim for last 3 years (if yes, then provide name and phone, qutoes will be given after call)
    #if df.loc[i, 'CLM_PST'] == 'YES':
    #    browser.find_element_by_xpath('//*[@id="tab3"]/div/div[2]/div/div/label[2]').click()
        
    #click next
    time.sleep(1)
    browser.find_element_by_xpath('//*[@id="tab3"]/div/ul/li[2]/a').click()
    time.sleep(1)
    
    #click confirm and get the quote
    browser.find_element_by_xpath('//*[@id="tab4"]/div[1]/button').click()
    
    time.sleep(4)
    html = browser.page_source
    # pass to BeautifulSoup parser
    soup = BeautifulSoup(html, "lxml")
    
    # Get basic plan
    name_box = soup.find_all('span', attrs={'class': 'plan-title'})

    basic_plan_name = name_box[0].text.strip()
    print basic_plan_name
    
    df.loc[i,'plan_name'] = basic_plan_name
    
    # Get price
    price_box = soup.find_all('p',attrs={'id':'plan_price_before_GST_1'})
    price = price_box[0].text.strip()
    
    df.loc[i,'plan_quotes'] = price
    
    time.sleep(1)
    # start a new quote
    url = 'https://insurance.income.com.sg/quote/car/index/'
    browser.get(url)
    # accept the alert 
    #browser.switch_to_alert().accept()
    time.sleep(1)
# Out:
# TOYOTA COROLLA ALTIS 1600 LESS_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1600 MORE_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1600 LESS_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1600 MORE_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1600 LESS_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1600 MORE_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1600 LESS_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1600 MORE_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1600 LESS_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1600 MORE_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1600 LESS_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1600 MORE_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1600 LESS_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1600 MORE_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1600 LESS_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1600 MORE_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1600 LESS_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1600 MORE_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1600 LESS_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1600 MORE_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1600 LESS_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1600 MORE_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1600 LESS_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1600 MORE_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1600 LESS_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1600 MORE_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1600 LESS_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1600 MORE_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1600 LESS_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1600 MORE_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1600 LESS_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1600 MORE_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1600 LESS_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1600 MORE_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1600 LESS_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1600 MORE_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1600 LESS_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1600 MORE_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1600 LESS_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1600 MORE_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1600 LESS_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1600 MORE_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1600 LESS_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1600 MORE_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1600 LESS_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1600 MORE_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1600 LESS_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1600 MORE_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1600 LESS_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1600 MORE_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1600 LESS_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1600 MORE_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1600 LESS_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1600 MORE_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1600 LESS_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1600 MORE_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1600 LESS_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1600 MORE_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1600 LESS_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1600 MORE_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1600 LESS_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1600 MORE_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1600 LESS_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1600 MORE_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1700 LESS_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1700 MORE_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1700 LESS_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1700 MORE_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1700 LESS_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1700 MORE_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1700 LESS_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1700 MORE_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1700 LESS_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1700 MORE_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1700 LESS_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1700 MORE_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1700 LESS_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1700 MORE_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1700 LESS_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1700 MORE_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1700 LESS_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1700 MORE_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1700 LESS_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1700 MORE_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1700 LESS_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1700 MORE_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1700 LESS_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1700 MORE_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1700 LESS_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1700 MORE_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1700 LESS_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1700 MORE_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1700 LESS_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1700 MORE_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1700 LESS_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1700 MORE_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1700 LESS_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1700 MORE_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1700 LESS_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1700 MORE_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1700 LESS_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1700 MORE_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1700 LESS_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1700 MORE_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1700 LESS_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1700 MORE_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1700 LESS_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1700 MORE_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1700 LESS_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1700 MORE_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1700 LESS_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1700 MORE_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1700 LESS_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1700 MORE_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1700 LESS_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1700 MORE_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1700 LESS_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1700 MORE_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1700 LESS_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1700 MORE_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1700 LESS_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1700 MORE_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1700 LESS_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1700 MORE_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1700 LESS_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1700 MORE_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1700 LESS_TWO NO
# Drivo Classic Plan
# TOYOTA COROLLA ALTIS 1700 MORE_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1600 LESS_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1600 MORE_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1600 LESS_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1600 MORE_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1600 LESS_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1600 MORE_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1600 LESS_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1600 MORE_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1600 LESS_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1600 MORE_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1600 LESS_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1600 MORE_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1600 LESS_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1600 MORE_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1600 LESS_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1600 MORE_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1600 LESS_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1600 MORE_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1600 LESS_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1600 MORE_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1600 LESS_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1600 MORE_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1600 LESS_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1600 MORE_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1600 LESS_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1600 MORE_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1600 LESS_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1600 MORE_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1600 LESS_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1600 MORE_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1600 LESS_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1600 MORE_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1600 LESS_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1600 MORE_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1600 LESS_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1600 MORE_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1600 LESS_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1600 MORE_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1600 LESS_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1600 MORE_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1600 LESS_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1600 MORE_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1600 LESS_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1600 MORE_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1600 LESS_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1600 MORE_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1600 LESS_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1600 MORE_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1600 LESS_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1600 MORE_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1600 LESS_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1600 MORE_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1600 LESS_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1600 MORE_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1600 LESS_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1600 MORE_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1600 LESS_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1600 MORE_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1600 LESS_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1600 MORE_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1600 LESS_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1600 MORE_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1600 LESS_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1600 MORE_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1700 LESS_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1700 MORE_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1700 LESS_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1700 MORE_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1700 LESS_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1700 MORE_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1700 LESS_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1700 MORE_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1700 LESS_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1700 MORE_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1700 LESS_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1700 MORE_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1700 LESS_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1700 MORE_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1700 LESS_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1700 MORE_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1700 LESS_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1700 MORE_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1700 LESS_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1700 MORE_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1700 LESS_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1700 MORE_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1700 LESS_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1700 MORE_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1700 LESS_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1700 MORE_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1700 LESS_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1700 MORE_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1700 LESS_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1700 MORE_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1700 LESS_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1700 MORE_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1700 LESS_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1700 MORE_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1700 LESS_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1700 MORE_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1700 LESS_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1700 MORE_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1700 LESS_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1700 MORE_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1700 LESS_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1700 MORE_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1700 LESS_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1700 MORE_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1700 LESS_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1700 MORE_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1700 LESS_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1700 MORE_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1700 LESS_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1700 MORE_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1700 LESS_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1700 MORE_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1700 LESS_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1700 MORE_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1700 LESS_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1700 MORE_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1700 LESS_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1700 MORE_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1700 LESS_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1700 MORE_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1700 LESS_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1700 MORE_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1700 LESS_TWO NO
# Drivo Classic Plan
# HONDA CIVIC 1700 MORE_TWO NO
# Drivo Classic Plan

# %%
df.to_csv('C:/Users/liuleo/Documents/KT/WEB_SCRAP/ntuc_ex.csv',index=False, sep='|')

# %%
df
# Out:
#                 CAR_MODEL  tmp_key CAR_ENGINE CAR_REGIS OFF_PEAK  GENDER  \
# 0    TOYOTA COROLLA ALTIS        1       1600      2016      YES    MALE
# 1    TOYOTA COROLLA ALTIS        1       1600      2016      YES    MALE
# 2    TOYOTA COROLLA ALTIS        1       1600      2016      YES    MALE
# 3    TOYOTA COROLLA ALTIS        1       1600      2016      YES    MALE
# 4    TOYOTA COROLLA ALTIS        1       1600      2016      YES    MALE
# 5    TOYOTA COROLLA ALTIS        1       1600      2016      YES    MALE
# 6    TOYOTA COROLLA ALTIS        1       1600      2016      YES    MALE
# 7    TOYOTA COROLLA ALTIS        1       1600      2016      YES    MALE
# 8    TOYOTA COROLLA ALTIS        1       1600      2016      YES  FEMALE
# 9    TOYOTA COROLLA ALTIS        1       1600      2016      YES  FEMALE
# 10   TOYOTA COROLLA ALTIS        1       1600      2016      YES  FEMALE
# 11   TOYOTA COROLLA ALTIS        1       1600      2016      YES  FEMALE
# 12   TOYOTA COROLLA ALTIS        1       1600      2016      YES  FEMALE
# 13   TOYOTA COROLLA ALTIS        1       1600      2016      YES  FEMALE
# 14   TOYOTA COROLLA ALTIS        1       1600      2016      YES  FEMALE
# 15   TOYOTA COROLLA ALTIS        1       1600      2016      YES  FEMALE
# 16   TOYOTA COROLLA ALTIS        1       1600      2016       NO    MALE
# 17   TOYOTA COROLLA ALTIS        1       1600      2016       NO    MALE
# 18   TOYOTA COROLLA ALTIS        1       1600      2016       NO    MALE
# 19   TOYOTA COROLLA ALTIS        1       1600      2016       NO    MALE
# 20   TOYOTA COROLLA ALTIS        1       1600      2016       NO    MALE
# 21   TOYOTA COROLLA ALTIS        1       1600      2016       NO    MALE
# 22   TOYOTA COROLLA ALTIS        1       1600      2016       NO    MALE
# 23   TOYOTA COROLLA ALTIS        1       1600      2016       NO    MALE
# 24   TOYOTA COROLLA ALTIS        1       1600      2016       NO  FEMALE
# 25   TOYOTA COROLLA ALTIS        1       1600      2016       NO  FEMALE
# 26   TOYOTA COROLLA ALTIS        1       1600      2016       NO  FEMALE
# 27   TOYOTA COROLLA ALTIS        1       1600      2016       NO  FEMALE
# 28   TOYOTA COROLLA ALTIS        1       1600      2016       NO  FEMALE
# 29   TOYOTA COROLLA ALTIS        1       1600      2016       NO  FEMALE
# ..                    ...      ...        ...       ...      ...     ...
# 226           HONDA CIVIC        1       1700      2017      YES    MALE
# 227           HONDA CIVIC        1       1700      2017      YES    MALE
# 228           HONDA CIVIC        1       1700      2017      YES    MALE
# 229           HONDA CIVIC        1       1700      2017      YES    MALE
# 230           HONDA CIVIC        1       1700      2017      YES    MALE
# 231           HONDA CIVIC        1       1700      2017      YES    MALE
# 232           HONDA CIVIC        1       1700      2017      YES  FEMALE
# 233           HONDA CIVIC        1       1700      2017      YES  FEMALE
# 234           HONDA CIVIC        1       1700      2017      YES  FEMALE
# 235           HONDA CIVIC        1       1700      2017      YES  FEMALE
# 236           HONDA CIVIC        1       1700      2017      YES  FEMALE
# 237           HONDA CIVIC        1       1700      2017      YES  FEMALE
# 238           HONDA CIVIC        1       1700      2017      YES  FEMALE
# 239           HONDA CIVIC        1       1700      2017      YES  FEMALE
# 240           HONDA CIVIC        1       1700      2017       NO    MALE
# 241           HONDA CIVIC        1       1700      2017       NO    MALE
# 242           HONDA CIVIC        1       1700      2017       NO    MALE
# 243           HONDA CIVIC        1       1700      2017       NO    MALE
# 244           HONDA CIVIC        1       1700      2017       NO    MALE
# 245           HONDA CIVIC        1       1700      2017       NO    MALE
# 246           HONDA CIVIC        1       1700      2017       NO    MALE
# 247           HONDA CIVIC        1       1700      2017       NO    MALE
# 248           HONDA CIVIC        1       1700      2017       NO  FEMALE
# 249           HONDA CIVIC        1       1700      2017       NO  FEMALE
# 250           HONDA CIVIC        1       1700      2017       NO  FEMALE
# 251           HONDA CIVIC        1       1700      2017       NO  FEMALE
# 252           HONDA CIVIC        1       1700      2017       NO  FEMALE
# 253           HONDA CIVIC        1       1700      2017       NO  FEMALE
# 254           HONDA CIVIC        1       1700      2017       NO  FEMALE
# 255           HONDA CIVIC        1       1700      2017       NO  FEMALE
#
#      MARITAL   BIRTHDATE   DRI_EXP CLM_PST           plan_name plan_quotes
# 0     SINGLE  01/01/1993  LESS_TWO      NO  Drivo Classic Plan
# 1     SINGLE  01/01/1993  MORE_TWO      NO  Drivo Classic Plan   $1,657.50
# 2     SINGLE  01/01/1983  LESS_TWO      NO  Drivo Classic Plan   $1,422.22
# 3     SINGLE  01/01/1983  MORE_TWO      NO  Drivo Classic Plan   $1,156.40
# 4    MARRIED  01/01/1993  LESS_TWO      NO  Drivo Classic Plan   $2,038.52
# 5    MARRIED  01/01/1993  MORE_TWO      NO  Drivo Classic Plan   $1,657.50
# 6    MARRIED  01/01/1983  LESS_TWO      NO  Drivo Classic Plan   $1,422.22
# 7    MARRIED  01/01/1983  MORE_TWO      NO  Drivo Classic Plan   $1,156.40
# 8     SINGLE  01/01/1993  LESS_TWO      NO  Drivo Classic Plan   $1,921.50
# 9     SINGLE  01/01/1993  MORE_TWO      NO  Drivo Classic Plan   $1,562.35
# 10    SINGLE  01/01/1983  LESS_TWO      NO  Drivo Classic Plan   $1,379.56
# 11    SINGLE  01/01/1983  MORE_TWO      NO  Drivo Classic Plan   $1,121.70
# 12   MARRIED  01/01/1993  LESS_TWO      NO  Drivo Classic Plan   $1,921.50
# 13   MARRIED  01/01/1993  MORE_TWO      NO  Drivo Classic Plan   $1,562.35
# 14   MARRIED  01/01/1983  LESS_TWO      NO  Drivo Classic Plan   $1,379.56
# 15   MARRIED  01/01/1983  MORE_TWO      NO  Drivo Classic Plan   $1,121.70
# 16    SINGLE  01/01/1993  LESS_TWO      NO  Drivo Classic Plan   $2,739.60
# 17    SINGLE  01/01/1993  MORE_TWO      NO  Drivo Classic Plan   $2,227.55
# 18    SINGLE  01/01/1983  LESS_TWO      NO  Drivo Classic Plan   $1,911.35
# 19    SINGLE  01/01/1983  MORE_TWO      NO  Drivo Classic Plan   $1,554.10
# 20   MARRIED  01/01/1993  LESS_TWO      NO  Drivo Classic Plan   $2,739.60
# 21   MARRIED  01/01/1993  MORE_TWO      NO  Drivo Classic Plan   $2,227.55
# 22   MARRIED  01/01/1983  LESS_TWO      NO  Drivo Classic Plan   $1,911.35
# 23   MARRIED  01/01/1983  MORE_TWO      NO  Drivo Classic Plan   $1,554.10
# 24    SINGLE  01/01/1993  LESS_TWO      NO  Drivo Classic Plan   $2,582.33
# 25    SINGLE  01/01/1993  MORE_TWO      NO  Drivo Classic Plan   $2,099.67
# 26    SINGLE  01/01/1983  LESS_TWO      NO  Drivo Classic Plan   $1,854.01
# 27    SINGLE  01/01/1983  MORE_TWO      NO  Drivo Classic Plan   $1,507.48
# 28   MARRIED  01/01/1993  LESS_TWO      NO  Drivo Classic Plan   $2,582.33
# 29   MARRIED  01/01/1993  MORE_TWO      NO  Drivo Classic Plan   $2,099.67
# ..       ...         ...       ...     ...                 ...         ...
# 226   SINGLE  01/01/1983  LESS_TWO      NO  Drivo Classic Plan   $1,801.63
# 227   SINGLE  01/01/1983  MORE_TWO      NO  Drivo Classic Plan   $1,464.89
# 228  MARRIED  01/01/1993  LESS_TWO      NO  Drivo Classic Plan   $2,582.33
# 229  MARRIED  01/01/1993  MORE_TWO      NO  Drivo Classic Plan   $2,099.67
# 230  MARRIED  01/01/1983  LESS_TWO      NO  Drivo Classic Plan   $1,801.63
# 231  MARRIED  01/01/1983  MORE_TWO      NO  Drivo Classic Plan   $1,464.89
# 232   SINGLE  01/01/1993  LESS_TWO      NO  Drivo Classic Plan   $2,434.10
# 233   SINGLE  01/01/1993  MORE_TWO      NO  Drivo Classic Plan   $1,979.15
# 234   SINGLE  01/01/1983  LESS_TWO      NO  Drivo Classic Plan   $1,747.58
# 235   SINGLE  01/01/1983  MORE_TWO      NO  Drivo Classic Plan   $1,420.95
# 236  MARRIED  01/01/1993  LESS_TWO      NO  Drivo Classic Plan   $2,434.10
# 237  MARRIED  01/01/1993  MORE_TWO      NO  Drivo Classic Plan   $1,979.15
# 238  MARRIED  01/01/1983  LESS_TWO      NO  Drivo Classic Plan   $1,747.58
# 239  MARRIED  01/01/1983  MORE_TWO      NO  Drivo Classic Plan   $1,420.95
# 240   SINGLE  01/01/1993  LESS_TWO      NO  Drivo Classic Plan   $3,470.44
# 241   SINGLE  01/01/1993  MORE_TWO      NO  Drivo Classic Plan   $2,821.78
# 242   SINGLE  01/01/1983  LESS_TWO      NO  Drivo Classic Plan   $2,421.24
# 243   SINGLE  01/01/1983  MORE_TWO      NO  Drivo Classic Plan   $1,968.69
# 244  MARRIED  01/01/1993  LESS_TWO      NO  Drivo Classic Plan   $3,470.44
# 245  MARRIED  01/01/1993  MORE_TWO      NO  Drivo Classic Plan   $2,821.78
# 246  MARRIED  01/01/1983  LESS_TWO      NO  Drivo Classic Plan   $2,421.24
# 247  MARRIED  01/01/1983  MORE_TWO      NO  Drivo Classic Plan   $1,968.69
# 248   SINGLE  01/01/1993  LESS_TWO      NO  Drivo Classic Plan   $3,271.23
# 249   SINGLE  01/01/1993  MORE_TWO      NO  Drivo Classic Plan   $2,659.81
# 250   SINGLE  01/01/1983  LESS_TWO      NO  Drivo Classic Plan   $2,348.61
# 251   SINGLE  01/01/1983  MORE_TWO      NO  Drivo Classic Plan   $1,909.63
# 252  MARRIED  01/01/1993  LESS_TWO      NO  Drivo Classic Plan   $3,271.23
# 253  MARRIED  01/01/1993  MORE_TWO      NO  Drivo Classic Plan   $2,659.81
# 254  MARRIED  01/01/1983  LESS_TWO      NO  Drivo Classic Plan   $2,348.61
# 255  MARRIED  01/01/1983  MORE_TWO      NO  Drivo Classic Plan   $1,909.63
#
# [256 rows x 12 columns]

# %%
# select car model 
select_car_model = Select(browser.find_element_by_id('carMakeModel'))
select_car_model.select_by_visible_text('TOYOTA COROLLA ALTIS')

# %%
# select car engine
select_car_eng = Select(browser.find_element_by_id('engineCapacities_car'))
select_car_eng.select_by_visible_text('1600')

# %% [raw]
# #method 2, take more time to run
#
# el = browser.find_element_by_id('engineCapacities_car')
#
# for opt in el.find_elements_by_tag_name('option'):
#     if opt.text == '1600':
#         opt.click()
#         break;

# %%
# sleep before input text 
time.sleep(1)
#input car registered year
browser.find_element_by_xpath('//*[@id="input-moto-year"]').send_keys('2016')

# %%
# select Off-Peak Car Scheme
browser.find_element_by_xpath('//*[@id="tab1"]/div/div[4]/div/div/label[1]').click()

# %%
#click next
browser.find_element_by_xpath('//*[@id="tab1"]/div/ul/li/a').click()
# sleep when goes to a new page
time.sleep(1)

# %%
# male and single. if change, use corresponding xpath
time.sleep(1)
#input date of birth
browser.find_element_by_xpath('//*[@id="date"]').send_keys('01/01/1993')

# %%
#click next
browser.find_element_by_xpath('//*[@id="tab2"]/div/ul/li[2]/a').click()
time.sleep(1)

# %%
#choose more than 2 years exp
browser.find_element_by_xpath('//*[@id="tab3"]/div/div[1]/div/div[1]/label[2]').click()

#for claims in past 3 years, choose no (default value)

#for NCD value (keep 0% for default)
# if need i times 10% values, then run the following with i times
#browser.find_element_by_xpath('//*[@id="tab3"]/div/div[3]/div/div[1]/span[2]/button').click()

#date
# start from the following day and contract lenght one year

# %%
#click next
browser.find_element_by_xpath('//*[@id="tab3"]/div/ul/li[2]/a').click()
time.sleep(1)

# %%
#click confirm and get the quote
browser.find_element_by_xpath('//*[@id="tab4"]/div[1]/button').click()

# %%
time.sleep(1)
html = browser.page_source
# pass to BeautifulSoup parser
soup = BeautifulSoup(html, "lxml")

# %%
# Get basic plan
name_box = soup.find_all('span', attrs={'class': 'plan-title'})

basic_plan_name = name_box[0].text.strip()
print basic_plan_name

# %%
# Get price
price_box = soup.find_all('p',attrs={'id':'plan_price_before_GST_1'})
print price_box[0].text.strip()

# %%
time.sleep(1)
# start a new quote
url = 'https://insurance.income.com.sg/quote/car/index/'
browser.get(url)
# accept the alert 
#browser.switch_to_alert().accept()
time.sleep(1)
