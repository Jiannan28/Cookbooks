# %%
import selenium
from bs4 import BeautifulSoup
import urllib2
import json

import re
from selenium import webdriver
from selenium.webdriver import ActionChains
from selenium.webdriver.support.ui import Select
import time

import pandas as pd
import numpy as np

from __future__ import division

# %%
CAR_MAKE_DICT = {
    'TOYOTA' : 5,
    'MERCEDES' : 4,
    'HONDA' : 3,
    'VOLKSWAGEN': 6,
    'HYUNDAI': 25,
    'BMW': 2,
    'NISSAN': 36,
    'AUDI': 9,
    'MAZDA': 32,
    'LEXUS': 31
}

# %%
gb_df = pd.read_csv('C:/Users/liuleo/Documents/KT/WEB_SCRAP/RISK_PROFILES_gobear.csv')

# %%
# change value type
gb_df['BIRTH_YEAR'] = gb_df['DOB'].apply(lambda x : x[0:4])
gb_df['BIRTH_YEAR'] = gb_df['BIRTH_YEAR'].astype(np.int32)
gb_df['LICENCE YEARS'] = gb_df['LICENCE YEARS'].astype(np.int8)
gb_df['NCD'] = gb_df['NCD'].astype(np.int8)

#modify the manufacture year to reflect current time (2015 to 2017)
gb_df['YEAR OF MANUFACTURE'] = gb_df['YEAR OF MANUFACTURE'] + 2
gb_df['YEAR OF MANUFACTURE'] = gb_df['YEAR OF MANUFACTURE'].astype(np.int32)

# if occupation and martial status available in the site
gb_df['OCCUPATION_FLAG'] = gb_df['OCCUPATION'].apply(lambda x : 1 if x in ['INDOOR MIDDLE LVL MGMT', 'OUTDOOR SALES/STAFF'] else 0)
gb_df['MARITAL_STATUS_FLAG'] = gb_df['MARITAL STATUS'].apply(lambda x : 1 if x in ['SINGLE', 'MARRIED'] else 0)

# %%
def concat_str(x):
    return x['MODEL'] + ' ' + str(x['CC'])

gb_df['MODEL_CC'] = gb_df.apply(concat_str, axis=1)

# %%
# check if profile contains empty or not
gb_df.isnull().sum()
# Out:
# RISK                           0
# MAKE                           0
# MODEL                          0
# CC                             0
# REGISTRATION DATE              0
# OFF PEAK                       0
# DOB                            0
# AGE OF DRIVER                  0
# GENDER                         0
# OCCUPATION                     0
# LICENCE YEARS                  0
# NCD                            0
# CLAIMS MADE IN LAST 3 YEARS    0
# COVER START DATE               0
# YEAR OF MANUFACTURE            0
# POLICY EXCESS                  0
# CAR OWNERSHIP YEARS            0
# MARITAL STATUS                 0
# BIRTH_YEAR                     0
# MODEL_CC                       0
# dtype: int64

# %%
gb_df_sample = gb_df[gb_df['MODEL']=='COROLLA ALTIS'].sample(2).reset_index(drop=True)
gb_df_sample
# Out:
#    RISK    MAKE          MODEL    CC REGISTRATION DATE OFF PEAK         DOB  \
# 0   424  TOYOTA  COROLLA ALTIS  1598         29/2/2016       NO  1991-01-21
# 1    46  TOYOTA  COROLLA ALTIS  1598         29/2/2016       NO  1978-01-01
#
#    AGE OF DRIVER  GENDER              OCCUPATION  LICENCE YEARS  NCD  \
# 0             27  FEMALE  INDOOR MIDDLE LVL MGMT              9   50
# 1             40    MALE  INDOOR MIDDLE LVL MGMT             22   50
#
#    CLAIMS MADE IN LAST 3 YEARS COVER START DATE  YEAR OF MANUFACTURE  \
# 0                            0        29/2/2016                 2017
# 1                            0        29/2/2016                 2017
#
#    POLICY EXCESS CAR OWNERSHIP YEARS MARITAL STATUS  BIRTH_YEAR  \
# 0            500              1-2YRS         SINGLE        1991
# 1            500              1-2YRS         SINGLE        1978
#
#              MODEL_CC
# 0  COROLLA ALTIS 1598
# 1  COROLLA ALTIS 1598

# %%
#initialize selenium chrom driver
path_to_chromedriver = 'C:\Users\liuleo\Documents\Python\chromedriver_win32\chromedriver.exe' 
browser = webdriver.Chrome(executable_path = path_to_chromedriver)

# %%
# navigate to the webpage containing information to be crawled
url = 'https://www.gobear.com/sg'
browser.get(url)

# %%
# go to car panel
browser.find_element_by_xpath('//*[@id="Insurance"]/div/ul/li[1]/a').click()

# %%
n=3

for i in range(0,len(gb_df_sample)):
    
    print 'Scraping Model:{} Customer BIR YEAR: {} Customer Gender: {} Customer Marital: {}'.format(gb_df_sample.loc[i,'MODEL'],
                                                                                                    gb_df_sample.loc[i,'BIRTH_YEAR'], 
                                                                                                    gb_df_sample.loc[i,'GENDER'], 
                                                                                                    gb_df_sample.loc[i,'MARITAL STATUS'])
    
    
    # select age
    browser.find_element_by_class_name('age-holder').click()

    browser.find_element_by_name('year').click()
    # send year
    browser.find_element_by_name('year').send_keys(gb_df_sample.loc[i,'BIRTH_YEAR'])
    time.sleep(1)
    ###

    # select marital status
    browser.find_element_by_xpath('//*[@id="car-form"]/div[1]/div[1]/div[2]/button').click()
    time.sleep(0.5)
    
    if gb_df_sample.loc[i,'MARITAL STATUS'] == 'SINGLE':
        #single
        browser.find_element_by_xpath('//*[@id="car-form"]/div[1]/div[1]/div[2]/div/ul/li[1]/a/link').click()
    elif gb_df_sample.loc[i,'MARITAL STATUS'] == 'MARRIED':
        #married
        browser.find_element_by_xpath('//*[@id="car-form"]/div[1]/div[1]/div[2]/div/ul/li[2]/a/link').click()
    else:
        continue
    ###

    # select gender
    browser.find_element_by_xpath('//*[@id="car-form"]/div[1]/div[1]/div[3]/div/button').click()
    time.sleep(0.5)
    
    if gb_df_sample.loc[i,'GENDER'] == 'MALE':
        # Male
        browser.find_element_by_xpath('//*[@id="car-form"]/div[1]/div[1]/div[3]/div/div/ul/li[1]/a/link').click()
    elif gb_df_sample.loc[i,'GENDER'] == 'FEMALE':
        # Female
        browser.find_element_by_xpath('//*[@id="car-form"]/div[1]/div[1]/div[3]/div/div/ul/li[2]/a/link').click()
    else:
        continue
    ###

    # select driving exp
    browser.find_element_by_xpath('//*[@id="car-form"]/div[1]/div[1]/div[4]/button').click()
    time.sleep(0.5)
    
    if gb_df_sample.loc[i,'LICENCE YEARS'] >=15:
        browser.find_element_by_xpath('//*[@id="car-form"]/div[1]/div[1]/div[4]/div/ul/li[16]/a/link').click()
    else:
        tmp_exp = str(gb_df_sample.loc[i,'LICENCE YEARS']+1)
        browser.find_element_by_xpath('//*[@id="car-form"]/div[1]/div[1]/div[4]/div/ul/li[' + tmp_exp + ']/a/link').click()
    time.sleep(0.5)
    ###

    # select NCD (no claim discount)
    browser.find_element_by_xpath('//*[@id="car-form"]/div[1]/div[2]/div/div[1]/button').click()
    time.sleep(1)
    
    tmp_ncd = str((gb_df_sample.loc[i,'NCD'] / 10) + 1)
    browser.find_element_by_xpath('//*[@id="car-form"]/div[1]/div[2]/div/div[1]/div/ul/li[' + tmp_ncd + ']/a/link').click()
    time.sleep(0.5)
    ###
    
    
    # select year 
    browser.find_element_by_xpath('//*[@id="carDetails"]/div[1]/div/button').click()
    time.sleep(1)
    
    tmp_car_year = 2020-gb_df_sample.loc[i,'YEAR OF MANUFACTURE'] #2018+2
    browser.find_element_by_xpath('//*[@id="carDetails"]/div[1]/div/div/ul/li[' + str(tmp_car_year) + ']/a/link').click()
    time.sleep(0.5)
    ###
    
    # select brand
    browser.find_element_by_xpath('//*[@id="carDetails"]/div[2]/div/button').click()
    time.sleep(1)
    
    tmp_car_make = CAR_MAKE_DICT[gb_df_sample.loc[i,'MAKE']]
    browser.find_element_by_xpath('//*[@id="carDetails"]/div[2]/div/div/ul/li[' + str(tmp_car_make) + ']/a/link').click()
    time.sleep(0.5)
    ###
    
    # select  model
    browser.find_element_by_xpath('//*[@id="carDetails"]/div[3]/div/button').click()
    time.sleep(1)
    #choose COROLLA ALTIS 1.6
    tmp_car_model = CAR_MODEL_DICT[gb_df_sample.loc[i,'MODEL']]
    browser.find_element_by_xpath(tmp_car_model).click()

    # click show my results (non- peak)
    browser.find_element_by_xpath('//*[@id="car-form"]/div[2]/div[2]/button[1]/link').click()
    time.sleep(5)
    
    ### navigate to other page already

    # click radio button for peak quotes
    if gb_df_sample.loc[i,'OFF PEAK'] == 'NO':
        browser.find_element_by_xpath('//*[@id="detailCollapse"]/div[2]/div[1]/label').click()
        time.sleep(5)
    
    

    # navigate to the webpage containing information to be crawled
    url = 'https://www.gobear.com/sg'
    browser.get(url)

    time.sleep(1)
    
    browser.find_element_by_xpath('//*[@id="Insurance"]/div/ul/li[1]/a').click()
    time.sleep(0.3)
# Out:
# Scraping Model:COROLLA ALTIS Customer BIR YEAR: 1991 Customer Gender: FEMALE Customer Marital: SINGLE
# Scraping Model:COROLLA ALTIS Customer BIR YEAR: 1978 Customer Gender: MALE Customer Marital: SINGLE

# %%
CAR_MODEL_DICT = {
    'COROLLA ALTIS 1598': '//*[@id="carDetails"]/div[3]/div/div/ul/li[3]/a/link',
    'BASE GRANDE' : 'NA',
    'ALLION 1797' : '//*[@id="carDetails"]/div[3]/div/div/ul/li[13]/a/link',
    'ALPHARD 2362': '//*[@id="carDetails"]/div[3]/div/div/ul/li[15]/a/link',
    'ALPHARD 2494': '//*[@id="carDetails"]/div[3]/div/div/ul/li[16]/a/link',
    'ALPHARD 3456': '//*[@id="carDetails"]/div[3]/div/div/ul/li[19]/a/link',
    'AURIS 1496': '//*[@id="carDetails"]/div[3]/div/div/ul/li[27]/a/link',
    'AURIS 1598': '//*[@id="carDetails"]/div[3]/div/div/ul/li[28]/a/link',
    'AVANZA 1495': '//*[@id="carDetails"]/div[3]/div/div/ul/li[35]/a/link',
    'BB 1495': '//*[@id="carDetails"]/div[3]/div/div/ul/li[51]/a/link',
    'BB 1298': '//*[@id="carDetails"]/div[3]/div/div/ul/li[50]/a/link',
    'BELTA 996': '//*[@id="carDetails"]/div[3]/div/div/ul/li[52]/a/link',
    'BELTA 1296': '//*[@id="carDetails"]/div[3]/div/div/ul/li[53]/a/link',
    'CAMRY 1998': '//*[@id="carDetails"]/div[3]/div/div/ul/li[2]/a/link',
    'CAMRY 2164': '//*[@id="carDetails"]/div[3]/div/div/ul/li[60]/a/link',
    'CAMRY 2362': '//*[@id="carDetails"]/div[3]/div/div/ul/li[61]/a/link',
    'CAMRY 2494': '//*[@id="carDetails"]/div[3]/div/div/ul/li[62]/a/link',
    'COROLLA 1296': '//*[@id="carDetails"]/div[3]/div/div/ul/li[74]/a/link',
    'COROLLA 1497': '//*[@id="carDetails"]/div[3]/div/div/ul/li[76]/a/link',
    'COROLLA 1598': '//*[@id="carDetails"]/div[3]/div/div/ul/li[80]/a/link',
    'CROWN 2500': '//*[@id="carDetails"]/div[3]/div/div/ul/li[98]/a/link',
    'CROWN 2995': '//*[@id="carDetails"]/div[3]/div/div/ul/li[96]/a/link',
    'ESTIMA 2362': '//*[@id="carDetails"]/div[3]/div/div/ul/li[111]/a/link',
    'ESTIMA 3456': '//*[@id="carDetails"]/div[3]/div/div/ul/li[113]/a/link',
    'ESQUIRE 1797': '//*[@id="carDetails"]/div[3]/div/div/ul/li[110]/a/link',
    'ESQUIRE 1986' : 'NA',
    'ECHO 1299': '//*[@id="carDetails"]/div[3]/div/div/ul/li[107]/a/link',
    'HARRIER 1986': '//*[@id="carDetails"]/div[3]/div/div/ul/li[124]/a/link',
    'HARRIER 2362':'//*[@id="carDetails"]/div[3]/div/div/ul/li[128]/a/link',
    'HARRIER 2994': '//*[@id="carDetails"]/div[3]/div/div/ul/li[131]/a/link',
    'FORTUNER 2694': '//*[@id="carDetails"]/div[3]/div/div/ul/li[122]/a/link',
    'IPSUM 2362': '//*[@id="carDetails"]/div[3]/div/div/ul/li[138]/a/link',
    'IST 1298': '//*[@id="carDetails"]/div[3]/div/div/ul/li[144]/a/link',
    'IST 1496': '//*[@id="carDetails"]/div[3]/div/div/ul/li[146]/a/link',
    'LAND CRUISER 4700': '//*[@id="carDetails"]/div[3]/div/div/ul/li[150]/a/link', # new add
    'LAND CRUISER 3955': 'NA',
    'LAND CRUISER 2693': 'NA',
    'MARK X 2362': '//*[@id="carDetails"]/div[3]/div/div/ul/li[159]/a/link',
    'MARK X 2499': '//*[@id="carDetails"]/div[3]/div/div/ul/li[155]/a/link',
    'MARK X 2994': '//*[@id="carDetails"]/div[3]/div/div/ul/li[157]/a/link',
    'NOAH 1986': '//*[@id="carDetails"]/div[3]/div/div/ul/li[165]/a/link',
    'NOAH 1998': '//*[@id="carDetails"]/div[3]/div/div/ul/li[164]/a/link',
    'NOAH 1797': 'NA',
    'PASSO 996': '//*[@id="carDetails"]/div[3]/div/div/ul/li[166]/a/link',
    'PASSO 1329': '//*[@id="carDetails"]/div[3]/div/div/ul/li[167]/a/link',
    'PASSO 1496': '//*[@id="carDetails"]/div[3]/div/div/ul/li[168]/a/link', #new
    'PICNIC 1998': '//*[@id="carDetails"]/div[3]/div/div/ul/li[169]/a/link',
    'PICNIC 2400': '//*[@id="carDetails"]/div[3]/div/div/ul/li[170]/a/link', #new
    'PREMIO 1500': '//*[@id="carDetails"]/div[3]/div/div/ul/li[176]/a/link',
    'PREMIO 1794': '//*[@id="carDetails"]/div[3]/div/div/ul/li[178]/a/link',
    'PREMIO 1998': '//*[@id="carDetails"]/div[3]/div/div/ul/li[179]/a/link', #new
    'PREVIA 2362': '//*[@id="carDetails"]/div[3]/div/div/ul/li[180]/a/link',
    'PRIUS 1798': '//*[@id="carDetails"]/div[3]/div/div/ul/li[182]/a/link',
    'PRIUS HYBRID 1497': '//*[@id="carDetails"]/div[3]/div/div/ul/li[181]/a/link',
    'VANGUARD 2362': '//*[@id="carDetails"]/div[3]/div/div/ul/li[212]/a/link',
    'VANGUARD 2400': 'NA',
    'VANGUARD 3456': '//*[@id="carDetails"]/div[3]/div/div/ul/li[213]/a/link',
    'RACTICS 1296': '//*[@id="carDetails"]/div[3]/div/div/ul/li[184]/a/link',
    'RACTICS 1496': '//*[@id="carDetails"]/div[3]/div/div/ul/li[185]/a/link',
    'RAV 4 1794': '//*[@id="carDetails"]/div[3]/div/div/ul/li[187]/a/link',
    'RAV 4 1798': 'NA',
    'RAV 4 1987': '//*[@id="carDetails"]/div[3]/div/div/ul/li[189]/a/link',
    'RAV 4 1998': '//*[@id="carDetails"]/div[3]/div/div/ul/li[188]/a/link',
    'RAV 4 2362': '//*[@id="carDetails"]/div[3]/div/div/ul/li[190]/a/link',
    'RAV 4 2400': '//*[@id="carDetails"]/div[3]/div/div/ul/li[191]/a/link', #new
    'SIENTA 1496': '//*[@id="carDetails"]/div[3]/div/div/ul/li[198]/a/link',
    'SOLUNA 1498': '//*[@id="carDetails"]/div[3]/div/div/ul/li[200]/a/link',
    'VELLFIRE 2362': '//*[@id="carDetails"]/div[3]/div/div/ul/li[214]/a/link',
    'VELLFIRE 2493': '//*[@id="carDetails"]/div[3]/div/div/ul/li[216]/a/link',
    'VELLFIRE 3456': '//*[@id="carDetails"]/div[3]/div/div/ul/li[217]/a/link',
    'VIOS 1497': '//*[@id="carDetails"]/div[3]/div/div/ul/li[5]/a/link',
    'VIOS 1500': 'NA',
    'VIOS J 1497': 'NA',
    'VITZ 996': '//*[@id="carDetails"]/div[3]/div/div/ul/li[224]/a/link',
    'VITZ 1296': '//*[@id="carDetails"]/div[3]/div/div/ul/li[225]/a/link',
    'VITZ 1329': '//*[@id="carDetails"]/div[3]/div/div/ul/li[227]/a/link',
    'VOXY 1998': '//*[@id="carDetails"]/div[3]/div/div/ul/li[229]/a/link',
    'VOXY 1986': 'NA',
    'WINDOM 2994': '//*[@id="carDetails"]/div[3]/div/div/ul/li[232]/a/link',
    'WINDOM 2496': '//*[@id="carDetails"]/div[3]/div/div/ul/li[231]/a/link', #new
    'WISH 1794': '//*[@id="carDetails"]/div[3]/div/div/ul/li[6]/a/link',
    'WISH 1986': '//*[@id="carDetails"]/div[3]/div/div/ul/li[234]/a/link',
    'YARIS 998': '//*[@id="carDetails"]/div[3]/div/div/ul/li[236]/a/link', #new
    'YARIS 1299': 'NA',
    'YARIS 1329': '//*[@id="carDetails"]/div[3]/div/div/ul/li[237]/a/link',
    'YARIS 1496': 'NA',
    'YARIS 1497': '//*[@id="carDetails"]/div[3]/div/div/ul/li[238]/a/link',
    'YARIS 1798': '//*[@id="carDetails"]/div[3]/div/div/ul/li[239]/a/link', #new
    ### MERCEDES
    'E200 1998': '//*[@id="carDetails"]/div[3]/div/div/ul/li[6]/a/link', #new
    'E200 1796': '//*[@id="carDetails"]/div[3]/div/div/ul/li[238]/a/link',
    'E200 BLUE EFFICIENCY 1796': '//*[@id="carDetails"]/div[3]/div/div/ul/li[234]/a/link',
    'E200 KOMPRESSOR 1796': '//*[@id="carDetails"]/div[3]/div/div/ul/li[240]/a/link',
    'E200 ELEGANCE 1796': 'NA',
    'E200 ESTATE 1796': '//*[@id="carDetails"]/div[3]/div/div/ul/li[238]/a/link',
    'CLA200 1595': '//*[@id="carDetails"]/div[3]/div/div/ul/li[165]/a/link',
    'CLA220 2143': '//*[@id="carDetails"]/div[3]/div/div/ul/li[169]/a/link',
    'CLA250 1991': '//*[@id="carDetails"]/div[3]/div/div/ul/li[170]/a/link',
    'S300L 2996': '//*[@id="carDetails"]/div[3]/div/div/ul/li[410]/a/link',
    'A150 1498': '//*[@id="carDetails"]/div[3]/div/div/ul/li[25]/a/link',
    'A160 1598': '//*[@id="carDetails"]/div[3]/div/div/ul/li[27]/a/link',
    'A170 1699': '//*[@id="carDetails"]/div[3]/div/div/ul/li[31]/a/link',
    'A190 1898': '//*[@id="carDetails"]/div[3]/div/div/ul/li[36]/a/link',
    'B160 1498': '//*[@id="carDetails"]/div[3]/div/div/ul/li[45]/a/link',
    'B170 1699': '//*[@id="carDetails"]/div[3]/div/div/ul/li[46]/a/link',
    'B180 1595': '//*[@id="carDetails"]/div[3]/div/div/ul/li[50]/a/link',
    'B180 1699': '//*[@id="carDetails"]/div[3]/div/div/ul/li[48]/a/link',
    'B200 2034': '//*[@id="carDetails"]/div[3]/div/div/ul/li[52]/a/link',
    'C180 1595': '//*[@id="carDetails"]/div[3]/div/div/ul/li[59]/a/link',
    'C200 1991': '//*[@id="carDetails"]/div[3]/div/div/ul/li[80]/a/link',
    'C230 2496': '//*[@id="carDetails"]/div[3]/div/div/ul/li[100]/a/link',
    'C350 3498': '//*[@id="carDetails"]/div[3]/div/div/ul/li[136]/a/link',
    ### VOLKSWAGEN
    'JETTA 1390': '//*[@id="carDetails"]/div[3]/div/div/ul/li[3]/a/link',
    'JETTA 1400': 'NA',
    'JETTA 1595': '//*[@id="carDetails"]/div[3]/div/div/ul/li[82]/a/link',
    'JETTA 1984': '//*[@id="carDetails"]/div[3]/div/div/ul/li[83]/a/link',
    'JETTA 2000': '//*[@id="carDetails"]/div[3]/div/div/ul/li[84]/a/link',
    'JETTA SPORT 1390': '//*[@id="carDetails"]/div[3]/div/div/ul/li[92]/a/link',
    'JETTA 1197': '//*[@id="carDetails"]/div[3]/div/div/ul/li[80]/a/link', #new
    'GOLF 1197': '//*[@id="carDetails"]/div[3]/div/div/ul/li[58]/a/link',
    'GOLF 1390': '//*[@id="carDetails"]/div[3]/div/div/ul/li[60]/a/link',
    'GOLF 1598': '//*[@id="carDetails"]/div[3]/div/div/ul/li[61]/a/link',
    'GOLF VARIANT 1595': '//*[@id="carDetails"]/div[3]/div/div/ul/li[75]/a/link',
    'PASSAT 1390': '//*[@id="carDetails"]/div[3]/div/div/ul/li[117]/a/link',
    'PASSAT 1781': 'NA',
    'PASSAT 1798': '//*[@id="carDetails"]/div[3]/div/div/ul/li[121]/a/link',
    'PASSAT 1968': 'NA',
    'PASSAT 1984': '//*[@id="carDetails"]/div[3]/div/div/ul/li[124]/a/link',
    'PASSAT CC 1798': '//*[@id="carDetails"]/div[3]/div/div/ul/li[138]/a/link',
    'PASSAT CC 1984': '//*[@id="carDetails"]/div[3]/div/div/ul/li[139]/a/link',
    'PASSAT 1595': '//*[@id="carDetails"]/div[3]/div/div/ul/li[121]/a/link',
    'PASSAT 1895': '//*[@id="carDetails"]/div[3]/div/div/ul/li[122]/a/link',
    'POLO 1197': 'NA',
    'POLO 1390': '//*[@id="carDetails"]/div[3]/div/div/ul/li[4]/a/link',
    'POLO 1598': '//*[@id="carDetails"]/div[3]/div/div/ul/li[154]/a/link',
    'POLO 1896': '//*[@id="carDetails"]/div[3]/div/div/ul/li[156]/a/link',
    ### LEXUS
    'ES250 2494': '//*[@id="carDetails"]/div[3]/div/div/ul/li[8]/a/link',
    'ES300 HYBRID 2494': '//*[@id="carDetails"]/div[3]/div/div/ul/li[6]/a/link',
    'ES300 HYBRID 2996': '//*[@id="carDetails"]/div[3]/div/div/ul/li[9]/a/link',
    'GS300 2995': '//*[@id="carDetails"]/div[3]/div/div/ul/li[16]/a/link',
    'GS250 2500': '//*[@id="carDetails"]/div[3]/div/div/ul/li[15]/a/link',
    'GS350 3456': '//*[@id="carDetails"]/div[3]/div/div/ul/li[17]/a/link',
    'IS200 1988': '//*[@id="carDetails"]/div[3]/div/div/ul/li[29]/a/link',
    'IS250 2499': '//*[@id="carDetails"]/div[3]/div/div/ul/li[30]/a/link',
    'IS350 3456': '//*[@id="carDetails"]/div[3]/div/div/ul/li[34]/a/link',
    'RX270 2672': '//*[@id="carDetails"]/div[3]/div/div/ul/li[55]/a/link',
    'RX300 2995': '//*[@id="carDetails"]/div[3]/div/div/ul/li[56]/a/link',
    'RX350 3456': '//*[@id="carDetails"]/div[3]/div/div/ul/li[60]/a/link',
    'RX400 3311': '//*[@id="carDetails"]/div[3]/div/div/ul/li[61]/a/link',
    #BMW
    '316i 1598': '//*[@id="carDetails"]/div[3]/div/div/ul/li[23]/a/link',
    '318i 1995': '//*[@id="carDetails"]/div[3]/div/div/ul/li[32]/a/link',
    '320i 1995': '//*[@id="carDetails"]/div[3]/div/div/ul/li[5]/a/link',
    '320i 2171': '//*[@id="carDetails"]/div[3]/div/div/ul/li[38]/a/link',
    '323i 1995': 'NA',
    '323i 2497': '//*[@id="carDetails"]/div[3]/div/div/ul/li[44]/a/link',
    '323i 2315': '//*[@id="carDetails"]/div[3]/div/div/ul/li[43]/a/link', #new
    '325i 2494': '//*[@id="carDetails"]/div[3]/div/div/ul/li[48]/a/link',
    '325i 2497': '//*[@id="carDetails"]/div[3]/div/div/ul/li[49]/a/link',
    '328i 1997': '//*[@id="carDetails"]/div[3]/div/div/ul/li[51]/a/link',
    '330i 2979': '//*[@id="carDetails"]/div[3]/div/div/ul/li[60]/a/link',
    '335i 2979': '//*[@id="carDetails"]/div[3]/div/div/ul/li[61]/a/link',
    '520i 2171': '//*[@id="carDetails"]/div[3]/div/div/ul/li[69]/a/link',
    '520i 1995': '//*[@id="carDetails"]/div[3]/div/div/ul/li[68]/a/link',
    '523i 2996': '//*[@id="carDetails"]/div[3]/div/div/ul/li[71]/a/link',
    '528i 1997': '//*[@id="carDetails"]/div[3]/div/div/ul/li[76]/a/link',
    '530i 2996': '//*[@id="carDetails"]/div[3]/div/div/ul/li[80]/a/link',
    ### Nissan
    'SYLPHY 1498': '//*[@id="carDetails"]/div[3]/div/div/ul/li[135]/a/link',
    'SYLPHY 1598': '//*[@id="carDetails"]/div[3]/div/div/ul/li[136]/a/link',
    'SYLPHY 1799': '//*[@id="carDetails"]/div[3]/div/div/ul/li[138]/a/link',
    'SYLPHY 1997': '//*[@id="carDetails"]/div[3]/div/div/ul/li[140]/a/link',
    'SUNNY 1498': '//*[@id="carDetails"]/div[3]/div/div/ul/li[129]/a/link',
    'SUNNY 1597': '//*[@id="carDetails"]/div[3]/div/div/ul/li[133]/a/link',
    'TEANA 1997': '//*[@id="carDetails"]/div[3]/div/div/ul/li[142]/a/link',
    'TEANA 2496': '//*[@id="carDetails"]/div[3]/div/div/ul/li[144]/a/link',
    'TEANA 3498': '//*[@id="carDetails"]/div[3]/div/div/ul/li[149]/a/link',
    'CEFIRO 1998': '//*[@id="carDetails"]/div[3]/div/div/ul/li[23]/a/link',
    'CEFIRO 2349': '//*[@id="carDetails"]/div[3]/div/div/ul/li[24]/a/link',
    'CEFIRO 2987': '//*[@id="carDetails"]/div[3]/div/div/ul/li[26]/a/link',
    'CEFIRO 3498': '//*[@id="carDetails"]/div[3]/div/div/ul/li[27]/a/link',
    'JUKE 1598': '//*[@id="carDetails"]/div[3]/div/div/ul/li[49]/a/link',
    'JUKE 1618': '//*[@id="carDetails"]/div[3]/div/div/ul/li[51]/a/link',
    'JUKE 1498': '//*[@id="carDetails"]/div[3]/div/div/ul/li[48]/a/link',
    ### AUDI
    'A6 1781': '//*[@id="carDetails"]/div[3]/div/div/ul/li[56]/a/link',
    'A6 1968': 'NA',
    'A6 1999': '//*[@id="carDetails"]/div[3]/div/div/ul/li[60]/a/link', #new
    'A6 1984': '//*[@id="carDetails"]/div[3]/div/div/ul/li[61]/a/link',
    'A6 2393': '//*[@id="carDetails"]/div[3]/div/div/ul/li[64]/a/link',
    'A5 1798': '//*[@id="carDetails"]/div[3]/div/div/ul/li[46]/a/link',
    'A5 2967': '//*[@id="carDetails"]/div[3]/div/div/ul/li[52]/a/link',
    'A7 1984': '//*[@id="carDetails"]/div[3]/div/div/ul/li[84]/a/link',
    'A4 CABRIOLET 1781': '//*[@id="carDetails"]/div[3]/div/div/ul/li[28]/a/link',
    'A4 CABRIOLET 1984': '//*[@id="carDetails"]/div[3]/div/div/ul/li[34]/a/link',
    'A4 CABRIOLET 2393': '//*[@id="carDetails"]/div[3]/div/div/ul/li[35]/a/link',
    'A3 CABRIOLET 1798': '//*[@id="carDetails"]/div[3]/div/div/ul/li[19]/a/link',
    'A3 CABRIOLET 1395': '//*[@id="carDetails"]/div[3]/div/div/ul/li[14]/a/link',
    'A3 1395': 'NA',
    'A3 1390': '//*[@id="carDetails"]/div[3]/div/div/ul/li[15]/a/link',
    'A3 1984': '//*[@id="carDetails"]/div[3]/div/div/ul/li[21]/a/link',
    'Q3 1395': 'NA',
    'Q3 1984': '//*[@id="carDetails"]/div[3]/div/div/ul/li[109]/a/link',
    'Q3 1968': '//*[@id="carDetails"]/div[3]/div/div/ul/li[108]/a/link',
    ### HYUNDAI
    'ELANTRA 1599': '//*[@id="carDetails"]/div[3]/div/div/ul/li[21]/a/link',
    'TUCSON 1975': 'NA',
    'TUCSON 1997': '//*[@id="carDetails"]/div[3]/div/div/ul/li[122]/a/link',
    'TUCSON 2359': '//*[@id="carDetails"]/div[3]/div/div/ul/li[123]/a/link',
    'TUCSON 2656': '//*[@id="carDetails"]/div[3]/div/div/ul/li[124]/a/link',
    'GETZ 1086': '//*[@id="carDetails"]/div[3]/div/div/ul/li[47]/a/link',
    'GETZ 1345': '//*[@id="carDetails"]/div[3]/div/div/ul/li[48]/a/link',
    'GETZ 1399': '//*[@id="carDetails"]/div[3]/div/div/ul/li[49]/a/link',
    'GETZ 1495': '//*[@id="carDetails"]/div[3]/div/div/ul/li[50]/a/link',
    'GETZ 1599': '//*[@id="carDetails"]/div[3]/div/div/ul/li[51]/a/link',
    'SANTA FE 2351': '//*[@id="carDetails"]/div[3]/div/div/ul/li[94]/a/link',
    'SANTA FE 2656': '//*[@id="carDetails"]/div[3]/div/div/ul/li[95]/a/link',
    'ACCENT 1368': '//*[@id="carDetails"]/div[3]/div/div/ul/li[3]/a/link',
    'ACCENT 1341': '//*[@id="carDetails"]/div[3]/div/div/ul/li[2]/a/link',
    'ACCENT 1495': '//*[@id="carDetails"]/div[3]/div/div/ul/li[5]/a/link',
    'AVANTE 1591': '//*[@id="carDetails"]/div[3]/div/div/ul/li[9]/a/link',
    'AVANTE 1998': '//*[@id="carDetails"]/div[3]/div/div/ul/li[10]/a/link',
    'TUSCANI 1975': '//*[@id="carDetails"]/div[3]/div/div/ul/li[125]/a/link',
    'TUSCANI 2656': '//*[@id="carDetails"]/div[3]/div/div/ul/li[126]/a/link', #new
    ### MAZDA
    '3 1598': '//*[@id="carDetails"]/div[3]/div/div/ul/li[11]/a/link',
    '3 1999': '//*[@id="carDetails"]/div[3]/div/div/ul/li[12]/a/link',
    '6 1999': '//*[@id="carDetails"]/div[3]/div/div/ul/li[42]/a/link',
    '6 2261': '//*[@id="carDetails"]/div[3]/div/div/ul/li[44]/a/link',
    '6 2488': '//*[@id="carDetails"]/div[3]/div/div/ul/li[45]/a/link',
    '8 2261': '//*[@id="carDetails"]/div[3]/div/div/ul/li[62]/a/link',
    'CX5 2488': '//*[@id="carDetails"]/div[3]/div/div/ul/li[73]/a/link',
    'CX7 2260': '//*[@id="carDetails"]/div[3]/div/div/ul/li[76]/a/link',
    'CX7 2488': '//*[@id="carDetails"]/div[3]/div/div/ul/li[78]/a/link',
    'CX9 3726': '//*[@id="carDetails"]/div[3]/div/div/ul/li[79]/a/link',
    'MPV 2967': '//*[@id="carDetails"]/div[3]/div/div/ul/li[96]/a/link',
    'AXELA 1497': '//*[@id="carDetails"]/div[3]/div/div/ul/li[68]/a/link',
    'BIANTE 1998': '//*[@id="carDetails"]/div[3]/div/div/ul/li[69]/a/link',
    'PREMACY 1991': '//*[@id="carDetails"]/div[3]/div/div/ul/li[106]/a/link',
    'DEMIO 1348': '//*[@id="carDetails"]/div[3]/div/div/ul/li[82]/a/link',
    ### HONDA
    'FIT 1317': '//*[@id="carDetails"]/div[3]/div/div/ul/li[78]/a/link',
    'FIT 1339': '//*[@id="carDetails"]/div[3]/div/div/ul/li[2]/a/link',
    'FIT 1496': '//*[@id="carDetails"]/div[3]/div/div/ul/li[80]/a/link',
    'JAZZ 1318': 'NA',
    'JAZZ 1198': '//*[@id="carDetails"]/div[3]/div/div/ul/li[105]/a/link',#new
    'JAZZ 1339': '//*[@id="carDetails"]/div[3]/div/div/ul/li[3]/a/link',
    'JAZZ 1496': '//*[@id="carDetails"]/div[3]/div/div/ul/li[4]/a/link',
    'ODYSSEY 2254': '//*[@id="carDetails"]/div[3]/div/div/ul/li[118]/a/link',
    'ODYSSEY 2354': '//*[@id="carDetails"]/div[3]/div/div/ul/li[120]/a/link',
    'ODYSSEY 2997': '//*[@id="carDetails"]/div[3]/div/div/ul/li[121]/a/link',
    'CIVIC 1497': '//*[@id="carDetails"]/div[3]/div/div/ul/li[33]/a/link',
    'CIVIC 1595': '//*[@id="carDetails"]/div[3]/div/div/ul/li[34]/a/link',
    'CIVIC 1668': '//*[@id="carDetails"]/div[3]/div/div/ul/li[36]/a/link',
    'CIVIC 1799': '//*[@id="carDetails"]/div[3]/div/div/ul/li[37]/a/link',
    'CIVIC 1998' : '//*[@id="carDetails"]/div[3]/div/div/ul/li[40]/a/link',
    'STREAM 1668': '//*[@id="carDetails"]/div[3]/div/div/ul/li[135]/a/link',
    'STREAM 1799': '//*[@id="carDetails"]/div[3]/div/div/ul/li[5]/a/link',
    'STREAM 1998': '//*[@id="carDetails"]/div[3]/div/div/ul/li[138]/a/link',
    'AIRWAVE 1496': '//*[@id="carDetails"]/div[3]/div/div/ul/li[24]/a/link',
    'CR-V 1998': '//*[@id="carDetails"]/div[3]/div/div/ul/li[63]/a/link',
    'CR-V 2354': '//*[@id="carDetails"]/div[3]/div/div/ul/li[66]/a/link',
    'EDIX 1668': '//*[@id="carDetails"]/div[3]/div/div/ul/li[71]/a/link',
    'EDIX 1998': '//*[@id="carDetails"]/div[3]/div/div/ul/li[72]/a/link',
    'VEZEL 1496': '//*[@id="carDetails"]/div[3]/div/div/ul/li[6]/a/link' #NEW    
}

# %%
browser.find_element_by_xpath('//*[@id="carDetails"]/div[3]/div/div/ul/li[3]/a/link').click()

# %%
# slide bar to move to excess level
slidebar =  browser.find_element_by_xpath('//*[@id="collapseThree"]/div[3]/div/div')
height = slidebar.size['height']
width = slidebar.size['width']
print height
print width

move = ActionChains(browser)
sliderknob = browser.find_element_by_xpath('//*[@id="collapseThree"]/div[3]/div/div/div[6]')
tmp_move = width - (gb_df[i,'POLICY EXCESS'] * width) / 1500 
move.click_and_hold(sliderknob).move_by_offset(-tmp_move, 0).release().perform()
#move.click_and_hold(sliderknob).move_by_offset(-(2/3)*width, 0).release().perform()

# %%
# select age
browser.find_element_by_class_name('age-holder').click()

browser.find_element_by_name('year').click()

browser.find_element_by_name('year').send_keys(1973)

time.sleep(1)

#click white area
#browser.find_element_by_xpath('//*[@id="app"]/div/div/section/div[2]/div/div[2]/div/div/div[2]/div/div[1]/div[2]/h1[2]').click()

# select marital status
browser.find_element_by_xpath('//*[@id="car-form"]/div[1]/div[1]/div[2]/button').click()
time.sleep(0.5)
#single
#browser.find_element_by_xpath('//*[@id="car-form"]/div[1]/div[1]/div[2]/div/ul/li[1]/a/link').click()
#married
browser.find_element_by_xpath('//*[@id="car-form"]/div[1]/div[1]/div[2]/div/ul/li[2]/a/link').click()

# select gender
browser.find_element_by_xpath('//*[@id="car-form"]/div[1]/div[1]/div[3]/div/button').click()
time.sleep(0.5)
# Male
#browser.find_element_by_xpath('//*[@id="car-form"]/div[1]/div[1]/div[3]/div/div/ul/li[1]/a/link').click()
# Female
browser.find_element_by_xpath('//*[@id="car-form"]/div[1]/div[1]/div[3]/div/div/ul/li[2]/a/link').click()

# select driving exp
browser.find_element_by_xpath('//*[@id="car-form"]/div[1]/div[1]/div[4]/button').click()
time.sleep(1)
# for 15+ exp
browser.find_element_by_xpath('//*[@id="car-form"]/div[1]/div[1]/div[4]/div/ul/li[16]/a/link').click()

# select NCD (no claim discount)
browser.find_element_by_xpath('//*[@id="car-form"]/div[1]/div[2]/div/div[1]/button').click()
time.sleep(1)
#here for 50% NCD
browser.find_element_by_xpath('//*[@id="car-form"]/div[1]/div[2]/div/div[1]/div/ul/li[6]/a/link').click()

# select year 
browser.find_element_by_xpath('//*[@id="carDetails"]/div[1]/div/button').click()
time.sleep(1)
#choose 2009
browser.find_element_by_xpath('//*[@id="carDetails"]/div[1]/div/div/ul/li[15]/a/link').click()

# select brand
browser.find_element_by_xpath('//*[@id="carDetails"]/div[2]/div/button').click()
time.sleep(1)
#choose Toyota
browser.find_element_by_xpath('//*[@id="carDetails"]/div[2]/div/div/ul/li[5]/a/link').click()

# select  model
browser.find_element_by_xpath('//*[@id="carDetails"]/div[3]/div/button').click()
time.sleep(1)
#choose COROLLA ALTIS 1.6
browser.find_element_by_xpath('//*[@id="carDetails"]/div[3]/div/div/ul/li[5]/a/link').click()

# click show my results (peak)
browser.find_element_by_xpath('//*[@id="car-form"]/div[2]/div[2]/button[1]/link').click()
time.sleep(5)

# click radio button for off-peak quotes
browser.find_element_by_xpath('//*[@id="detailCollapse"]/div[2]/div[2]/label').click()
time.sleep(5)

# navigate to the webpage containing information to be crawled
url = 'https://www.gobear.com/sg'
browser.get(url)

time.sleep(1)

# %%
# slide bar to move to excess level
slidebar =  browser.find_element_by_xpath('//*[@id="collapseThree"]/div[3]/div/div')
height = slidebar.size['height']
width = slidebar.size['width']
print height
print width

move = ActionChains(browser)
sliderknob = browser.find_element_by_xpath('//*[@id="collapseThree"]/div[3]/div/div/div[6]')
move.click_and_hold(sliderknob).move_by_offset(-18, 0).release().perform()
